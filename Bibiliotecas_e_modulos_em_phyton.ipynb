# %% [markdown]
# <a href="https://colab.research.google.com/github/Domingos336/Linguagem-de-programa-o/blob/main/Bibiliotecas_e_modulos_em_phyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Primeiro modo
import math

math.sqrt(415)
math.log2(3000)

math.cos(4417)
# Out:
# 0.9968597034159485

# %%
#Segundo modo
import math as m

m.sqrt(25)
m.log2(1024)

m.cos(45)
# Out:
# 0.5253219888177297

# %%
#Terceiro modo
from math import sqrt, log2, cos

sqrt(25)
log2(1024)
cos(45)
# Out:
# 0.5253219888177297

# %%
import matplotlib.pyplot as plt

# Dados
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [2, 4, 1, 3, 5, 7, 9, 10]

#Criar um gráfico de linha
plt.plot(x,y)

#Adicionar rótulos aos eixos
plt.xlabel('Eixo, X')
plt.ylabel("Eixo, Y")

# Adicionar um título ao gráfico
plt.title('Exemplo de Gráfico de linha')

# Mostrar o gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

#Dados de exemplos
meses = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho']
vendas = [1200, 1800, 2000, 1700, 4000, 5900, 3555]

#Criar um gráfico de barras
plt.bar(meses, vendas, color='orange')

#Adicionar um título ao gráfico
plt.title('Vendas Mensais')

#Mostrar o gráfico
plt.show()
